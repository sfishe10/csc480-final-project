# %%
# Install pyDatalog
# !pip install pyDatalog

from pyDatalog import pyDatalog
import re
import pandas as pd
# Out:
# Collecting pyDatalog
#   Downloading pyDatalog-0.17.4.tar.gz (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyDatalog
#   Building wheel for pyDatalog (pyproject.toml) ... done
#   Created wheel for pyDatalog: filename=pydatalog-0.17.4-py2.py3-none-any.whl size=74280 sha256=0fa18b35d0880fd1ecfd8c8112b221312dcb538333a6fa6834e2bdbe81d0e45f
#   Stored in directory: /root/.cache/pip/wheels/3d/86/49/61fd7f650165a5795f4b61720e1aeb2875f7e3f6d09de485be
# Successfully built pyDatalog
# Installing collected packages: pyDatalog
# Successfully installed pyDatalog-0.17.4

# %%
SHEET_ID = "1nZUKlY0F9DvsKG5au21Lsp2FMojRoVOW9luWJQkrdHM"
GID = "756887908"

csv_url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv&gid={GID}"
df = pd.read_csv(csv_url)

# Strip whitespace in string columns
for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].astype(str).str.strip()

# Convert empty strings to NA, then drop any row with any NA
df = df.replace(r"^\s*$", pd.NA, regex=True).dropna(how="any").reset_index(drop=True)

df.shape, df.head()
# Out:
# ((186, 37),
#                breed                                        description  \
#  0     Affenpinscher  The Affen’s apish look has been described many...
#  1      Afghan Hound  The Afghan Hound is an ancient breed, his whol...
#  2  Airedale Terrier  The Airedale Terrier is the largest of all ter...
#  3             Akita  Akitas are burly, heavy-boned spitz-type dogs ...
#  4  Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                   temperament popularity  min_height  \
#  0        Confident, Famously Funny, Fearless        148       22.86
#  1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
#  2               Friendly, Clever, Courageous         60       58.42
#  3    Courageous, Dignified, Profoundly Loyal         47       60.96
#  4               Affectionate, Loyal, Playful         58       58.42
#
#     max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
#  0       29.21    3.175147    4.535924            12.0            15.0  ...
#  1       68.58   22.679619   27.215542            12.0            15.0  ...
#  2       58.42   22.679619   31.751466            11.0            14.0  ...
#  3       71.12   31.751466   58.967008            10.0            13.0  ...
#  4       63.50   34.019428   38.555351            10.0            14.0  ...
#
#    Coat Type  Coat Length Openness To Strangers  Playfulness Level  \
#  0      Wiry        Short                   5.0                3.0
#  1     Silky         Long                   3.0                3.0
#  2      Wiry        Short                   3.0                3.0
#  3    Double       Medium                   2.0                3.0
#  4    Double       Medium                   3.0                3.0
#
#    Watchdog/Protective Nature  Adaptability Level Trainability Level  \
#  0                        3.0                 4.0                3.0
#  1                        3.0                 3.0                1.0
#  2                        5.0                 3.0                3.0
#  3                        5.0                 3.0                3.0
#  4                        4.0                 3.0                5.0
#
#     Energy Level Barking Level  Mental Stimulation Needs
#  0           3.0           3.0                       3.0
#  1           4.0           3.0                       3.0
#  2           3.0           3.0                       3.0
#  3           4.0           2.0                       3.0
#  4           4.0           3.0                       3.0
#
#  [5 rows x 37 columns])

# %%
def calculate_threshold_values(min_val, max_val):
  span = max_val - min_val
  t1 = min_val + span / 3.0
  t2 = min_val + 2.0 * span / 3.0

  return t1, t2

# %%
def categorize_numeric_value(value: float, t1: float, t2: float, cat1, cat2, cat3) -> str:
    if value <= t1:
        return cat1
    elif value <= t2:
        return cat2
    else:
        return cat3

#-------- Calculate threshold values for Size categories --------#

# Drop rows where either min or max weight is 0
df = df[(df["min_weight"] > 0) & (df["max_weight"] > 0)].reset_index(drop=True)

df["avg_weight"] = (df["min_weight"] + df["max_weight"]) / 2.0

min_avg = df["avg_weight"].min()
max_avg = df["avg_weight"].max()

t1, t2 = calculate_threshold_values(min_avg, max_avg)

df["size_class"] = df["avg_weight"].apply(lambda w: categorize_numeric_value(w, t1, t2, "Small", "Medium", "Large"))


#-------- Calculate threshold values for Good With Children categories --------#
t1, t2 = calculate_threshold_values(df["Good With Young Children"].min(), df["Good With Young Children"].max())
df["good_with_children_class"] = df["Good With Young Children"].apply(lambda v: categorize_numeric_value(v, t1, t2, "Bad_With_Children", "Ok_With_Children", "Good_With_Children"))


#-------- Calculate threshold values for Good With Other Dogs categories --------#
t1, t2 = calculate_threshold_values(df["Good With Other Dogs"].min(), df["Good With Other Dogs"].max())
df["good_with_other_dogs_class"] = df["Good With Other Dogs"].apply(lambda v: categorize_numeric_value(v, t1, t2, "Bad_With_Other_Dogs", "Ok_With_Other_Dogs", "Good_With_Other_Dogs"))


#-------- Calculate threshold values for Protectiveness categories --------#
t1, t2 = calculate_threshold_values(df["Watchdog/Protective Nature"].min(), df["Watchdog/Protective Nature"].max())
df["protectiveness_class"] = df["Watchdog/Protective Nature"].apply(lambda v: categorize_numeric_value(v, t1, t2, "Not_Protective", "Somewhat_Protective", "Very_Protective"))


#-------- Calculate threshold values for Barking Level categories --------#
t1, t2 = calculate_threshold_values(df["Barking Level"].min(), df["Barking Level"].max())
df["barking_level_class"] = df["Barking Level"].apply(lambda v: categorize_numeric_value(v, t1, t2, "Barks_Rarely", "Barks_Occasionally", "Barks_Often"))

# %%
pyDatalog.clear()

def to_term_name(breed: str) -> str:
    # Replace non-alphanumeric with underscore
    name = re.sub(r"[^0-9a-zA-Z_]+", "_", breed).strip("_")
    return name

breed_to_term = {breed: to_term_name(breed) for breed in df["breed"].unique()}
shedding_to_term = {shedding: ('Sheds_' + to_term_name(shedding)) for shedding in df["shedding_category"].unique()}
grooming_to_term = {grooming: ('Requires_' + to_term_name(grooming)) for grooming in df["grooming_frequency_category"].unique()}
energy_to_term = {energy: (to_term_name(energy)) for energy in df["energy_level_category"].unique()}
trainability_to_term = {trainability: (to_term_name(trainability)) for trainability in df["trainability_category"].unique()}
demeanor_to_term = {demeanor: (to_term_name(demeanor)) for demeanor in df["demeanor_category"].unique()}
coat_type_to_term = {coat_type: (to_term_name(coat_type) + "_Coat") for coat_type in df["Coat Type"].unique()}
coat_length_to_term = {coat_length: (to_term_name(coat_length) + "_Coat") for coat_length in df["Coat Length"].unique()}


# Create terms
all_breed_terms = sorted(set(breed_to_term.values()))
all_shedding_terms = sorted(set(shedding_to_term.values()))
all_grooming_terms = sorted(set(grooming_to_term.values()))
all_energy_terms = sorted(set(energy_to_term.values()))
all_trainability_terms = sorted(set(trainability_to_term.values()))
all_demeanor_terms = sorted(set(demeanor_to_term.values()))
all_coat_type_terms = sorted(set(coat_type_to_term.values()))
all_coat_length_terms = sorted(set(coat_length_to_term.values()))
terms_str = ", ".join(all_breed_terms
                      + all_shedding_terms
                      + all_grooming_terms
                      + all_energy_terms
                      + all_trainability_terms
                      + all_coat_type_terms
                      + all_coat_length_terms
                      + ["Small", "Medium", "Large"]
                      + ["B"]
                      + ["Bad_With_Children", "Ok_With_Children", "Good_With_Children"]
                      + ["Bad_With_Other_Dogs", "Ok_With_Other_Dogs", "Good_With_Other_Dogs"]
                      + ["Not_Protective", "Somewhat_Protective", "Very_Protective"]
                      + ["Barks_Rarely", "Barks_Occasionally", "Barks_Often"])

pyDatalog.create_terms(terms_str)

# Assert facts
for _, row in df.iterrows():
    breed = row["breed"]

    # size fact:
    size = globals()[row["size_class"]]
    +size(breed)

    # shedding fact:
    pred_name = shedding_to_term[row["shedding_category"]]
    shed_pred = globals()[pred_name]
    +shed_pred(breed)

    # grooming fact:
    pred_name = grooming_to_term[row["grooming_frequency_category"]]
    groom_pred = globals()[pred_name]
    +groom_pred(breed)

    # energy fact:
    pred_name = energy_to_term[row["energy_level_category"]]
    energy_pred = globals()[pred_name]
    +energy_pred(breed)

    # trainability fact:
    pred_name = trainability_to_term[row["trainability_category"]]
    trainability_pred = globals()[pred_name]
    +trainability_pred(breed)

    # demeanor fact:
    pred_name = demeanor_to_term[row["demeanor_category"]]
    demeanor_pred = globals()[pred_name]
    +demeanor_pred(breed)

    # good with children fact:
    good_with_children = globals()[row["good_with_children_class"]]
    +good_with_children(breed)

    # good with other dogs fact:
    good_with_other_dogs = globals()[row["good_with_other_dogs_class"]]
    +good_with_other_dogs(breed)

    # coat type fact:
    pred_name = coat_type_to_term[row["Coat Type"]]
    coat_type_pred = globals()[pred_name]
    +coat_type_pred(breed)

    # coat length fact:
    pred_name = coat_length_to_term[row["Coat Length"]]
    coat_length_pred = globals()[pred_name]
    +coat_length_pred(breed)

    # protectiveness fact:
    protectiveness = globals()[row["protectiveness_class"]]
    +protectiveness(breed)

    # barking level fact:
    barking_level = globals()[row["barking_level_class"]]
    +barking_level(breed)

# %%
# Query for breeds based on various criteria; return the breed name as it appears in the dataset

term_to_breed = {v: k for k, v in breed_to_term.items()}

def query_to_originals(query_result) -> list[str]:
    # query_result is something like: [(Affenpinscher,), (Afghan_Hound,), ...]
    originals = []
    for (term_obj,) in query_result:
        # term_obj prints like "Affenpinscher" — we map by string name
        originals.append(term_to_breed.get(str(term_obj), str(term_obj)))
    return originals

print("Small breeds:")
print(query_to_originals(Small(B).data)[:30])

print("\nRegular shedders:")
print(query_to_originals(Sheds_Regularly(B).data))

print("\nRequires Weekly Brushing:")
print(query_to_originals(Requires_Weekly_Brushing(B).data))

print("\nEnergetic Breeds:")
print(query_to_originals(Energetic(B).data))

print("\nIndependent Breeds:")
print(query_to_originals(Independent(B).data))

print("\nAlert/Responsive Breeds:")
print(query_to_originals(Alert_Responsive(B).data))

print("\nBreeds Ok with Children:")
print(query_to_originals(Ok_With_Children(B).data))

print("\nBreeds Good with Other Dogs:")
print(query_to_originals(Good_With_Other_Dogs(B).data))

print("\nBreeds with Smooth Coats:")
print(query_to_originals(Smooth_Coat(B).data))

print("\nBreeds with Long Coats:")
print(query_to_originals(Long_Coat(B).data))

print("\nVery Protective Breeds")
print(query_to_originals(Very_Protective(B).data))

print("\nQuiet Breeds")
print(query_to_originals(Barks_Rarely(B).data))
# Out:
# Small breeds:
# ['Yorkshire Terrier', 'Xoloitzcuintli', 'Wirehaired Vizsla', 'Wirehaired Pointing Griffon', 'Wire Fox Terrier', 'Whippet', 'West Highland White Terrier', 'Welsh Terrier', 'Vizsla', 'Treeing Walker Coonhound', 'Toy Fox Terrier', 'Tibetan Terrier', 'Tibetan Spaniel', 'Swedish Vallhund', 'Sussex Spaniel', 'Standard Schnauzer', 'Staffordshire Bull Terrier', 'Spanish Water Dog', 'Soft Coated Wheaten Terrier', 'Smooth Fox Terrier', 'Sloughi', 'Skye Terrier', 'Silky Terrier', 'Siberian Husky', 'Shih Tzu', 'Shiba Inu', 'Shetland Sheepdog', 'Sealyham Terrier', 'Scottish Terrier', 'Schipperke']
#
# Regular shedders:
# ['Pug', 'Pembroke Welsh Corgi', 'Leonberger', 'Labrador Retriever', 'Kuvasz', 'German Wirehaired Pointer', 'German Shorthaired Pointer', 'German Shepherd Dog', 'French Bulldog', 'Flat-Coated Retriever', 'Field Spaniel', 'English Setter', 'English Foxhound', 'Dogue de Bordeaux', 'Doberman Pinscher', 'Clumber Spaniel', 'Chinese Shar-Pei', 'Chesapeake Bay Retriever', 'Bulldog', 'Australian Cattle Dog']
#
# Requires Weekly Brushing:
# ['Wirehaired Pointing Griffon', 'Wire Fox Terrier', 'Weimaraner', 'Vizsla', 'Toy Fox Terrier', 'Tibetan Spaniel', 'Staffordshire Bull Terrier', 'Smooth Fox Terrier', 'Sloughi', 'Siberian Husky', 'Shiba Inu', 'Schipperke', 'Saint Bernard', 'Russell Terrier', 'Rottweiler', 'Rhodesian Ridgeback', 'Redbone Coonhound', 'Rat Terrier', 'Pyrenean Shepherd', 'Pug', 'Portuguese Podengo Pequeno', 'Pointer', 'Pharaoh Hound', 'Petit Basset Griffon Vendéen', 'Pembroke Welsh Corgi', 'Parson Russell Terrier', 'Papillon', 'Otterhound', 'Nova Scotia Duck Tolling Retriever', 'Norwich Terrier', 'Norwegian Lundehund', 'Norwegian Elkhound', 'Norwegian Buhund', 'Norfolk Terrier', 'Newfoundland', 'Nederlandse Kooikerhondje', 'Neapolitan Mastiff', 'Manchester Terrier (Standard)', 'Lakeland Terrier', 'Labrador Retriever', 'Kuvasz', 'Japanese Chin', 'Irish Wolfhound', 'Irish Water Spaniel', 'Icelandic Sheepdog', 'Harrier', 'Greater Swiss Mountain Dog', 'Great Pyrenees', 'Grand Basset Griffon Vendéen', 'Gordon Setter', 'Golden Retriever', 'German Wirehaired Pointer', 'German Shorthaired Pointer', 'German Shepherd Dog', 'Flat-Coated Retriever', 'Finnish Spitz', 'Finnish Lapphund', 'Field Spaniel', 'English Springer Spaniel', 'Dalmatian', 'Dachshund', 'Clumber Spaniel', 'Chinook', 'Cesky Terrier', 'Cavalier King Charles Spaniel', 'Cardigan Welsh Corgi', 'Canaan Dog', 'Cairn Terrier', 'Bull Terrier', 'Boxer', 'Boston Terrier', 'Borzoi', 'Border Terrier', 'Bluetick Coonhound', 'Bloodhound', 'Black and Tan Coonhound', 'Belgian Malinois', 'Barbet', 'Azawakh', 'Australian Terrier', 'Australian Shepherd', 'Anatolian Shepherd Dog', 'American Eskimo Dog']
#
# Energetic Breeds:
# ['Xoloitzcuintli', 'Wirehaired Vizsla', 'Welsh Terrier', 'Vizsla', 'Toy Fox Terrier', 'Tibetan Terrier', 'Staffordshire Bull Terrier', 'Spanish Water Dog', 'Soft Coated Wheaten Terrier', 'Smooth Fox Terrier', 'Siberian Husky', 'Schipperke', 'Samoyed', 'Saluki', 'Pyrenean Shepherd', 'Pumi', 'Portuguese Water Dog', 'Portuguese Podengo Pequeno', 'Polish Lowland Sheepdog', 'Pointer', 'Plott Hound', 'Pharaoh Hound', 'Petit Basset Griffon Vendéen', 'Pembroke Welsh Corgi', 'Norwich Terrier', 'Norwegian Lundehund', 'Norwegian Buhund', 'Miniature Bull Terrier', 'Miniature American Shepherd', 'Icelandic Sheepdog', 'Greyhound', 'Greater Swiss Mountain Dog', 'Great Dane', 'English Setter', 'English Foxhound', 'Dalmatian', 'Curly-Coated Retriever', 'Chinook', 'Chesapeake Bay Retriever', 'Cardigan Welsh Corgi', 'Bullmastiff', 'Bull Terrier', 'Boxer', 'Bouvier des Flandres', 'Borzoi', 'Bluetick Coonhound', 'Black Russian Terrier', 'Bernese Mountain Dog', 'Belgian Tervuren', 'Belgian Sheepdog', 'Belgian Malinois', 'Beagle', 'Basenji', 'Australian Terrier', 'Australian Shepherd', 'American Foxhound', 'American Eskimo Dog', 'American English Coonhound', 'Alaskan Malamute', 'Akita', 'Afghan Hound']
#
# Independent Breeds:
# ['Whippet', 'Treeing Walker Coonhound', 'Tibetan Terrier', 'Tibetan Mastiff', 'Sussex Spaniel', 'Standard Schnauzer', 'Soft Coated Wheaten Terrier', 'Sloughi', 'Skye Terrier', 'Siberian Husky', 'Shiba Inu', 'Sealyham Terrier', 'Scottish Terrier', 'Scottish Deerhound', 'Schipperke', 'Samoyed', 'Saluki', 'Rhodesian Ridgeback', 'Puli', 'Plott Hound', 'Pharaoh Hound', 'Petit Basset Griffon Vendéen', 'Old English Sheepdog', 'Miniature Pinscher', 'Miniature Bull Terrier', 'Lhasa Apso', 'Kuvasz', 'Komondor', 'Japanese Chin', 'Italian Greyhound', 'Irish Wolfhound', 'Ibizan Hound', 'Greyhound', 'Great Pyrenees', 'Grand Basset Griffon Vendéen', 'Gordon Setter', 'Glen of Imaal Terrier', 'Entlebucher Mountain Dog', 'English Toy Spaniel', 'Dandie Dinmont Terrier', 'Curly-Coated Retriever', 'Chihuahua', 'Canaan Dog', 'Bull Terrier', 'Briard', 'Borzoi', 'Bloodhound', 'Black and Tan Coonhound', 'Bearded Collie', 'Basset Hound', 'Basenji', 'Azawakh', 'Anatolian Shepherd Dog', 'American Foxhound', 'Alaskan Malamute']
#
# Alert/Responsive Breeds:
# ['Xoloitzcuintli', 'Wirehaired Vizsla', 'Wirehaired Pointing Griffon', 'Wire Fox Terrier', 'Tibetan Spaniel', 'Tibetan Mastiff', 'Soft Coated Wheaten Terrier', 'Silky Terrier', 'Sealyham Terrier', 'Scottish Terrier', 'Scottish Deerhound', 'Schipperke', 'Rhodesian Ridgeback', 'Pumi', 'Portuguese Water Dog', 'Pomeranian', 'Pointer', 'Plott Hound', 'Otterhound', 'Old English Sheepdog', 'Miniature Schnauzer', 'Miniature Pinscher', 'Miniature Bull Terrier', 'Mastiff', 'Manchester Terrier (Standard)', 'Lakeland Terrier', 'Lagotto Romagnolo', 'Irish Wolfhound', 'Greater Swiss Mountain Dog', 'Great Dane', 'Glen of Imaal Terrier', 'German Shepherd Dog', 'German Pinscher', 'French Bulldog', 'English Toy Spaniel', 'Dogue de Bordeaux', 'Doberman Pinscher', 'Dalmatian', 'Dachshund', 'Cirneco dell’Etna', 'Chihuahua', 'Cardigan Welsh Corgi', 'Bullmastiff', 'Boykin Spaniel', 'Bouvier des Flandres', 'Borzoi', 'Bloodhound', 'Berger Picard', 'Australian Shepherd', 'American Staffordshire Terrier', 'American English Coonhound', 'Akita']
#
# Breeds Ok with Children:
# ['Xoloitzcuintli', 'Toy Fox Terrier', 'Tibetan Terrier', 'Tibetan Mastiff', 'Sussex Spaniel', 'Smooth Fox Terrier', 'Sloughi', 'Skye Terrier', 'Silky Terrier', 'Shiba Inu', 'Sealyham Terrier', 'Scottish Terrier', 'Scottish Deerhound', 'Schipperke', 'Saluki', 'Russell Terrier', 'Rottweiler', 'Pyrenean Shepherd', 'Pumi', 'Puli', 'Pomeranian', 'Polish Lowland Sheepdog', 'Pointer', 'Plott Hound', 'Pharaoh Hound', 'Pembroke Welsh Corgi', 'Pekingese', 'Parson Russell Terrier', 'Otterhound', 'Norwegian Lundehund', 'Norwegian Elkhound', 'Norwegian Buhund', 'Nederlandse Kooikerhondje', 'Neapolitan Mastiff', 'Miniature Pinscher', 'Miniature Bull Terrier', 'Maltese', 'Lhasa Apso', 'Lakeland Terrier', 'Lagotto Romagnolo', 'Kuvasz', 'Komondor', 'Japanese Chin', 'Italian Greyhound', 'Irish Wolfhound', 'Irish Water Spaniel', 'Ibizan Hound', 'Greyhound', 'Great Pyrenees', 'Great Dane', 'Grand Basset Griffon Vendéen', 'Gordon Setter', 'Glen of Imaal Terrier', 'German Wirehaired Pointer', 'German Pinscher', 'Entlebucher Mountain Dog', 'English Springer Spaniel', 'Dogue de Bordeaux', 'Dandie Dinmont Terrier', 'Dalmatian', 'Dachshund', 'Clumber Spaniel', 'Cirneco dell’Etna', 'Chow Chow', 'Chinese Shar-Pei', 'Chinese Crested', 'Chesapeake Bay Retriever', 'Canaan Dog', 'Cairn Terrier', 'Bullmastiff', 'Bulldog', 'Bull Terrier', 'Brussels Griffon', 'Briard', 'Bouvier des Flandres', 'Borzoi', 'Border Collie', 'Bluetick Coonhound', 'Bloodhound', 'Black Russian Terrier', 'Berger Picard', 'Bergamasco Sheepdog', 'Belgian Tervuren', 'Belgian Sheepdog', 'Belgian Malinois', 'Beauceron', 'Basenji', 'Azawakh', 'Australian Cattle Dog', 'Anatolian Shepherd Dog', 'American Water Spaniel', 'American Staffordshire Terrier', 'American English Coonhound', 'Alaskan Malamute', 'Akita', 'Airedale Terrier', 'Afghan Hound', 'Affenpinscher']
#
# Breeds Good with Other Dogs:
# ['Whippet', 'Vizsla', 'Treeing Walker Coonhound', 'Siberian Husky', 'Shih Tzu', 'Shetland Sheepdog', 'Scottish Deerhound', 'Russell Terrier', 'Redbone Coonhound', 'Pug', 'Portuguese Water Dog', 'Portuguese Podengo Pequeno', 'Pointer', 'Plott Hound', 'Pharaoh Hound', 'Petit Basset Griffon Vendéen', 'Pembroke Welsh Corgi', 'Parson Russell Terrier', 'Nova Scotia Duck Tolling Retriever', 'Newfoundland', 'Miniature Pinscher', 'Miniature American Shepherd', 'Lagotto Romagnolo', 'Labrador Retriever', 'Keeshond', 'Japanese Chin', 'Italian Greyhound', 'Irish Wolfhound', 'Irish Setter', 'Icelandic Sheepdog', 'Ibizan Hound', 'Havanese', 'Harrier', 'Greyhound', 'Grand Basset Griffon Vendéen', 'Golden Retriever', 'German Shorthaired Pointer', 'French Bulldog', 'Flat-Coated Retriever', 'Finnish Spitz', 'Field Spaniel', 'Entlebucher Mountain Dog', 'English Toy Spaniel', 'English Springer Spaniel', 'English Setter', 'English Foxhound', 'English Cocker Spaniel', 'Dachshund', 'Coton de Tulear', 'Cocker Spaniel', 'Cirneco dell’Etna', 'Chinook', 'Cavalier King Charles Spaniel', 'Brittany', 'Boykin Spaniel', 'Boston Terrier', 'Bluetick Coonhound', 'Black and Tan Coonhound', 'Bichon Frise', 'Bernese Mountain Dog', 'Bearded Collie', 'Beagle', 'Basset Hound', 'Barbet', 'American Foxhound', 'American English Coonhound']
#
# Breeds with Smooth Coats:
# ['Whippet', 'Weimaraner', 'Vizsla', 'Treeing Walker Coonhound', 'Toy Fox Terrier', 'Staffordshire Bull Terrier', 'Smooth Fox Terrier', 'Sloughi', 'Saluki', 'Saint Bernard', 'Rottweiler', 'Rhodesian Ridgeback', 'Redbone Coonhound', 'Rat Terrier', 'Pyrenean Shepherd', 'Pug', 'Pointer', 'Plott Hound', 'Pharaoh Hound', 'Parson Russell Terrier', 'Neapolitan Mastiff', 'Miniature Pinscher', 'Miniature Bull Terrier', 'Manchester Terrier (Standard)', 'Italian Greyhound', 'Greyhound', 'Greater Swiss Mountain Dog', 'Great Dane', 'German Shorthaired Pointer', 'German Pinscher', 'French Bulldog', 'Flat-Coated Retriever', 'Field Spaniel', 'Entlebucher Mountain Dog', 'Dogue de Bordeaux', 'Doberman Pinscher', 'Dalmatian', 'Dachshund', 'Collie', 'Cirneco dell’Etna', 'Chow Chow', 'Chinook', 'Chinese Shar-Pei', 'Chihuahua', 'Canaan Dog', 'Bullmastiff', 'Bulldog', 'Bull Terrier', 'Boxer', 'Boston Terrier', 'Boerboel', 'Bluetick Coonhound', 'Bloodhound', 'Black and Tan Coonhound', 'Belgian Malinois', 'Beauceron', 'Beagle', 'Basset Hound', 'Basenji', 'Azawakh', 'Australian Cattle Dog', 'Anatolian Shepherd Dog', 'American Staffordshire Terrier', 'American Foxhound', 'American English Coonhound']
#
# Breeds with Long Coats:
# ['Yorkshire Terrier', 'Tibetan Terrier', 'Skye Terrier', 'Silky Terrier', 'Shih Tzu', 'Shetland Sheepdog', 'Samoyed', 'Puli', 'Portuguese Water Dog', 'Poodle (Standard)', 'Pomeranian', 'Polish Lowland Sheepdog', 'Petit Basset Griffon Vendéen', 'Pekingese', 'Old English Sheepdog', 'Maltese', 'Löwchen', 'Lhasa Apso', 'Leonberger', 'Komondor', 'Keeshond', 'Havanese', 'Coton de Tulear', 'Cocker Spaniel', 'Briard', 'Bichon Frise', 'Bergamasco Sheepdog', 'Bearded Collie', 'Afghan Hound']
#
# Very Protective Breeds
# ['Yorkshire Terrier', 'Wire Fox Terrier', 'West Highland White Terrier', 'Welsh Terrier', 'Weimaraner', 'Toy Fox Terrier', 'Tibetan Terrier', 'Tibetan Spaniel', 'Tibetan Mastiff', 'Standard Schnauzer', 'Staffordshire Bull Terrier', 'Smooth Fox Terrier', 'Silky Terrier', 'Shiba Inu', 'Shetland Sheepdog', 'Sealyham Terrier', 'Scottish Terrier', 'Schipperke', 'Samoyed', 'Saint Bernard', 'Russell Terrier', 'Rottweiler', 'Rhodesian Ridgeback', 'Rat Terrier', 'Pyrenean Shepherd', 'Pumi', 'Puli', 'Portuguese Water Dog', 'Poodle (Standard)', 'Pomeranian', 'Polish Lowland Sheepdog', 'Plott Hound', 'Petit Basset Griffon Vendéen', 'Pembroke Welsh Corgi', 'Pekingese', 'Papillon', 'Old English Sheepdog', 'Norwich Terrier', 'Norwegian Elkhound', 'Norwegian Buhund', 'Norfolk Terrier', 'Newfoundland', 'Neapolitan Mastiff', 'Miniature Schnauzer', 'Miniature Pinscher', 'Miniature Bull Terrier', 'Mastiff', 'Manchester Terrier (Standard)', 'Maltese', 'Löwchen', 'Lhasa Apso', 'Leonberger', 'Kuvasz', 'Komondor', 'Keeshond', 'Irish Wolfhound', 'Icelandic Sheepdog', 'Greater Swiss Mountain Dog', 'Great Pyrenees', 'Great Dane', 'Gordon Setter', 'German Shorthaired Pointer', 'German Shepherd Dog', 'German Pinscher', 'Entlebucher Mountain Dog', 'Dogue de Bordeaux', 'Doberman Pinscher', 'Dandie Dinmont Terrier', 'Dalmatian', 'Dachshund', 'Curly-Coated Retriever', 'Chow Chow', 'Chinook', 'Chinese Shar-Pei', 'Chihuahua', 'Chesapeake Bay Retriever', 'Canaan Dog', 'Cairn Terrier', 'Bullmastiff', 'Briard', 'Boxer', 'Bouvier des Flandres', 'Boerboel', 'Black Russian Terrier', 'Berger Picard', 'Bergamasco Sheepdog', 'Belgian Tervuren', 'Belgian Sheepdog', 'Belgian Malinois', 'Beauceron', 'Australian Terrier', 'Australian Cattle Dog', 'Anatolian Shepherd Dog', 'American Staffordshire Terrier', 'Alaskan Malamute', 'Akita', 'Airedale Terrier']
#
# Quiet Breeds
# ['Whippet', 'Sloughi', 'Scottish Deerhound', 'Saint Bernard', 'Rottweiler', 'Rhodesian Ridgeback', 'Pug', 'Pekingese', 'Nova Scotia Duck Tolling Retriever', 'Newfoundland', 'Neapolitan Mastiff', 'Mastiff', 'Lagotto Romagnolo', 'Japanese Chin', 'Irish Wolfhound', 'Irish Water Spaniel', 'Golden Retriever', 'Glen of Imaal Terrier', 'French Bulldog', 'English Toy Spaniel', 'Coton de Tulear', 'Clumber Spaniel', 'Cirneco dell’Etna', 'Chow Chow', 'Bullmastiff', 'Bulldog', 'Briard', 'Boston Terrier', 'Borzoi', 'Berger Picard', 'Bergamasco Sheepdog', 'Basenji', 'Azawakh', 'Australian Cattle Dog', 'Akita']
